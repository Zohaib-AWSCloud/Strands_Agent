# %% [markdown]
# # Strands Agents with Bedrock AgentCore Memory — FSI Edition
#
# This lab demonstrates persistent memory for AI agents — enabling them to remember client preferences, risk profiles, and past interactions across sessions.
#
# ## Overview
#
# In this lab, you will:
# - Create an AgentCore Memory instance with multiple strategies
# - Store FSI client conversations (risk appetite, migration plans)
# - Retrieve memories across sessions
# - Build a memory-enabled agent that personalizes responses
#
# ## Why Memory for FSI?
#
# - **Client continuity** — Agent remembers: "Vanguard prefers ESG, moderate risk"
# - **Handoff support** — New TAM gets full context without re-asking
# - **Compliance** — Auditable record of advice given
# - **Personalization** — Tailored recommendations based on history

# %% [markdown]
# ## Prerequisites

# %%
import os
#os.environ['AWS_ACCESS_KEY_ID'] = ''
#os.environ['AWS_SECRET_ACCESS_KEY'] = ''
#os.environ['AWS_SESSION_TOKEN'] = ''
#os.environ['AWS_REGION'] = ''

# %%
#%pip install -q strands-agents strands-agents-tools bedrock-agentcore rich

# %%
import boto3
region = boto3.session.Session().region_name
NOVA_PRO_MODEL_ID = 'us.amazon.nova-pro-v1:0'
if region.startswith('eu'): NOVA_PRO_MODEL_ID = 'eu.amazon.nova-pro-v1:0'
elif region.startswith('ap'): NOVA_PRO_MODEL_ID = 'apac.amazon.nova-pro-v1:0'
print(f'Region: {region}, Model: {NOVA_PRO_MODEL_ID}')

# %% [markdown]
# ## Demonstrating the Memory Problem
#
# Without persistent memory, every new session starts fresh:

# %%
from strands import Agent
from strands.models import BedrockModel

agent = Agent(
    model=BedrockModel(model_id=NOVA_PRO_MODEL_ID, max_tokens=4096),
    system_prompt='You are a financial advisor assistant.',
)

# Simulate: user told the agent about their client last week
# But in a new session, the agent has no memory of it
agent('What do you know about my client Vanguard and their risk preferences?')

# %% [markdown]
# ## Creating AgentCore Memory
#
# Let's create a memory instance with three strategies:
# - **Summary** — Compresses conversations into key points
# - **User Preferences** — Captures client preferences and patterns
# - **Semantic Facts** — Extracts factual knowledge from conversations
#
# ⏱️ This takes approximately 3 minutes to provision.

# %%
from bedrock_agentcore._utils import endpoints
import boto3
import time

cp_endpoint = endpoints.get_control_plane_endpoint(region)
dp_endpoint = endpoints.get_data_plane_endpoint(region)

cp_client = boto3.client('bedrock-agentcore-control', region_name=region, endpoint_url=cp_endpoint)
dp_client = boto3.client('bedrock-agentcore', region_name=region, endpoint_url=dp_endpoint)

# Create memory
memory_name = 'fsi_client_memory'
try:
    memory_response = cp_client.create_memory(
        name=memory_name,
        description='FSI client context memory for advisory agents',
        memoryStrategies=[
            {'strategyType': 'SUMMARY', 'configuration': {'maxSummaries': 100}},
            {'strategyType': 'USER_PREFERENCE', 'configuration': {'maxPreferences': 100}},
            {'strategyType': 'SEMANTIC', 'configuration': {'maxFacts': 200}},
        ],
        memoryExpirationConfiguration={'memoryExpirationDays': 365},
    )
    memory_id = memory_response['memoryId']
    print(f'✅ Memory created: {memory_id}')
    print('   Waiting for provisioning (~3 min)...')
except Exception as e:
    if 'already exists' in str(e).lower():
        memories = cp_client.list_memories()['memorySummaries']
        memory_id = next(m['memoryId'] for m in memories if m['name'] == memory_name)
        print(f'✅ Using existing memory: {memory_id}')
    else:
        raise e

# %% [markdown]
# ## Storing Client Conversations
#
# Let's simulate conversations about FSI clients and store them in memory:

# %%
import json
from datetime import datetime

# Simulate a conversation about Vanguard
vanguard_conversation = [
    {'role': 'user', 'content': 'My client Vanguard is a large super fund based in Australia. They manage over $200B in assets.'},
    {'role': 'assistant', 'content': 'Noted. Vanguard Australia is a major superannuation fund with $200B+ AUM.'},
    {'role': 'user', 'content': 'They have a moderate risk appetite and prefer ESG-aligned investments. They are migrating their core trading platform to EKS in Q3 2026.'},
    {'role': 'assistant', 'content': 'Understood. Key notes: moderate risk, ESG preference, EKS migration planned for Q3 2026.'},
    {'role': 'user', 'content': 'Their primary concern is latency - they need sub-10ms for trade execution in ap-southeast-2. The escalation contact is John Chen, CTO.'},
    {'role': 'assistant', 'content': 'Critical requirements noted: sub-10ms latency in ap-southeast-2 for trading. Escalation: John Chen (CTO).'},
]

# Store in memory
dp_client.create_memory_event(
    memoryId=memory_id,
    actorId='tam_zohaib',
    eventData={
        'type': 'CONVERSATION',
        'conversation': {
            'messages': [{'role': m['role'], 'content': [{'text': m['content']}]} for m in vanguard_conversation]
        }
    },
)
print('✅ Vanguard conversation stored')

# Store Afterpay conversation
afterpay_conversation = [
    {'role': 'user', 'content': 'Afterpay processes millions of BNPL transactions daily. They need real-time fraud detection with <100ms response time.'},
    {'role': 'assistant', 'content': 'Afterpay requirements: real-time fraud detection, <100ms latency, high transaction volume.'},
    {'role': 'user', 'content': 'They are concerned about ASIC regulatory changes to BNPL. Their preferred region is ap-southeast-2 with DR in us-west-2.'},
    {'role': 'assistant', 'content': 'Noted: ASIC regulatory risk, primary region ap-southeast-2, DR in us-west-2.'},
]

dp_client.create_memory_event(
    memoryId=memory_id,
    actorId='tam_zohaib',
    eventData={
        'type': 'CONVERSATION',
        'conversation': {
            'messages': [{'role': m['role'], 'content': [{'text': m['content']}]} for m in afterpay_conversation]
        }
    },
)
print('✅ Afterpay conversation stored')
print('\n⏱️ Wait 20-30 seconds for memory processing...')

# %% [markdown]
# ## Retrieving Memories
#
# Let's query the memory to see what was extracted:

# %%
import time
time.sleep(30)  # Wait for memory processing

# Retrieve all memories
memories = dp_client.retrieve_memory(
    memoryId=memory_id,
    actorId='tam_zohaib',
    query='What do I know about my FSI clients?',
)

print('=== Retrieved Memories ===')
for item in memories.get('memoryRecords', []):
    print(f"\nStrategy: {item.get('strategyType', 'unknown')}")
    print(f"Content: {item.get('content', {}).get('text', 'N/A')[:200]}")

# %% [markdown]
# ## Building a Memory-Enabled Agent
#
# Now let's create an agent that retrieves memory before responding:

# %%
from strands import Agent, tool
from strands.models import BedrockModel

@tool
def recall_client_context(query: str) -> str:
    '''Retrieve stored context about a client from memory.
    Args:
        query: What to recall (e.g., "Vanguard risk preferences")
    '''
    memories = dp_client.retrieve_memory(
        memoryId=memory_id,
        actorId='tam_zohaib',
        query=query,
    )
    records = memories.get('memoryRecords', [])
    if not records:
        return 'No stored context found for this query.'
    return '\n'.join(r.get('content', {}).get('text', '') for r in records[:5])

memory_agent = Agent(
    model=BedrockModel(model_id=NOVA_PRO_MODEL_ID, max_tokens=4096),
    system_prompt='''You are a financial services advisor with access to stored client context.
    Always check memory first when asked about a client. Provide personalized responses.''',
    tools=[recall_client_context],
)

# Test: Ask about Vanguard (agent should recall from memory)
memory_agent('What do you know about Vanguard? What are their key concerns and upcoming plans?')

# %%
# Test: Ask about Afterpay
memory_agent('What are Afterpay\'s requirements and regulatory concerns?')

# %% [markdown]
# ## Cleanup (Optional)

# %%
# Uncomment to clean up
# cp_client.delete_memory(memoryId=memory_id)
# print('✅ Memory deleted')

# %% [markdown]
# ## Summary
#
# - ✅ Created AgentCore Memory with summary, preference, and semantic strategies
# - ✅ Stored FSI client conversations (Vanguard, Afterpay)
# - ✅ Retrieved extracted insights (preferences, facts, summaries)
# - ✅ Built a memory-enabled agent that personalizes responses
#
# ### FSI Takeaways
#
# | Capability | FSI Value |
# |-----------|----------|
# | Persistent memory | Client context survives across sessions |
# | Preference extraction | Auto-captures risk appetite, region preferences |
# | Semantic facts | Stores key dates, contacts, requirements |
# | Cross-session continuity | TAM handoff without losing context |
#
# ## 🎉 Workshop Complete!
#
# You've built an FSI agent that can:
# - Calculate financial metrics (Lab 00)
# - Execute dynamic analysis code (Lab 01)
# - Browse regulatory websites (Lab 02)
# - Deploy tools as managed services (Lab 04)
# - Provide full audit trails (Lab 05)
# - Remember client context across sessions (Lab 06)
